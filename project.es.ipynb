# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de fotocasa, el cual es uno de los sitios mas populares de bienes raíces en España. Por favor no hagas estos (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa mas cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa mas cara en el todo el dataset? (★☆☆)
#
# Imprime la direccion y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
precio_maximo = ds['price'].max()

direccion_casa_cara = ds.loc[ds['price'].idxmax()]['address']
print("La dirección de la casa más cara esta en:", direccion_casa_cara , "Y su precio es", precio_maximo)
# Out:
# La dirección de la casa más cara esta en: El Escorial Y su precio es 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa mas barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
precio_minimo = ds[ds['price'] > 0]['price'].min()
precio_minimo
direccion_casa_barata = ds.loc[ds['price'].idxmin()]['address']
print("La dirección de la casa más cara es:", direccion_casa_barata , "Y su precio es", precio_minimo)
# Out:
# La dirección de la casa más cara es: Parla Y su precio es 600

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa mas grande y la mas pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el area de las casas seleccionadas. Por ejemplo:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
casa_masgrande = ds['surface'].max()
casa_maschica = ds['surface'].min()

direccion_casa_grande = ds.loc[ds['price'].idxmax()]['address']
direccion_casa_chica = ds.loc[ds['price'].idxmin()]['address']
print("La casa mas grande esta en ", direccion_casa_grande , "Y su superficie es", casa_masgrande, 'metros')
print("La casa mas chica esta en ", direccion_casa_chica , "Y su superficie es", casa_maschica , 'metros')
# Out:
# La casa mas grande esta en  El Escorial Y su superficie es 249000.0 metros
# La casa mas chica esta en  Parla Y su superficie es 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
level = ds['level5'].unique()

coma = ", ".join(level)
print("lista de suburbios es", coma )
# Out:
# lista de suburbios es Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# #### Ejercicio 05. ¿El data set contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`true` o `fase`) seguido de la fila/columna que contiene el NAs.

# %%
filas_con_nan = ds[ds.isna().any(axis=1)]

# Imprimir las filas con NaN
print(filas_con_nan)

columnas_con_nan = ds.columns[ds.isna().any()]

# Imprimir las columnas con NaN
print(columnas_con_nan)
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]
# Index(['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface',
#        'description', 'level4', 'level6', 'level7', 'level8', 'zipCode',
#        'customZone'],
#       dtype='object')

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del data set, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
#me quedo sin filas, todos tienen NAs
#solo los que tienen Nan en todas sus columans
ds = ds.dropna(how='all')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido

# %%
conteo_arroyomolinos = ds['level5'].value_counts().get('Arroyomolinos (Madrid)', 0)
conteo_arroyomolinos

arroyomolinos_data =  ds[(ds['level5'] == 'Arroyomolinos (Madrid)') & (ds['price'] != 0)]
arroyomolinos_data


promedio = arroyomolinos_data['price'].mean()
promedio
print('El promedio de precios del suburbio Arroyomolinos es :' , promedio)
# Out:
# El promedio de precios del suburbio Arroyomolinos es : 298905.1777777778

# %%
promedio_precios = ds['price'].mean()
promedio_precios
# Out:
# np.float64(477303.56641669385)

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt
arroyomolinos_data

plt.hist(arroyomolinos_data['price'], bins=10, color='blue', edgecolor='black')

plt.xlabel('Precio')
plt.ylabel('Cantidad')
plt.title('Histograma de precios de Arroyomolinos')


plt.show()

# %%
#298905 477303
# El Promedio de precios en Arromolinos es mas bajo considerando el promedio del ds Total que es 477303
#volvere

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en este celda y elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿ Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedio y escribe una conclusion acerca de ellos

# %%
conteo_valdemorrillo = ds['level5'].value_counts().get('Valdemorrillo', 0)


valdemorrillo_data =  ds[(ds['level5'] == 'Valdemorrillo') & (ds['price'] != 0)]
valdemorrillo_data


promedio_val = valdemorrillo_data['price'].mean()
promedio_val


conteo_valdemorrillo = ds['level5'].value_counts().get('Valdemorrillo', 0)

# %%
conteo_valdemorrillo = ds['level5'].value_counts().get('Valdemorrillo', 0)

print(conteo_valdemorrillo)


conteo_galapagar = ds['level5'].value_counts().get('Galapagar', 0)

print(conteo_galapagar)

Galapagar_data =  ds[(ds['level5'] == 'Galapagar') & (ds['price'] != 0)]
Galapagar_data


promedio_gal = Galapagar_data['price'].mean()
promedio_gal
# Out:
# 0
# 84
# np.float64(360063.20238095237)

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (price/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio y escribe una conclusion acerca de ellos.
#
# Pista: Crea una nueva columna llamada `pps` (price per square) y luego analiza los valore.s

# %%
ds['precio/mt2'] = ds['price'] / ds['surface']

prom_Valdemorillo = ds[ds['level5'] == 'Valdemorrillo']['precio/mt2'].mean()
prom_Galapagar = ds[ds['level5'] == 'Galapagar']['precio/mt2'].mean()
print(f'Precio promedio por mt2 en Valdemorillo: {prom_Valdemorillo:.2f}')
print(f'Precio promedio por mt2 en Galapagar: {prom_Galapagar:.2f}')
if prom_Valdemorillo == prom_Galapagar:
    print('Ambos promedios en este caso  son iguales')
else:
    print('el precio promediopor mt2 no son iguales')
# Out:
# Precio promedio por mt2 en Valdemorillo: nan
# Precio promedio por mt2 en Galapagar: 1606.32
# el precio promediopor mt2 no son iguales

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusion al respecto.

# %%
plt.scatter(range(len(ds['price'])), ds['price'], color='blue', alpha=0.5)

plt.xlabel('Indice')
plt.ylabel('Precio')
plt.title('Gráfico de "price"')
plt.show()

ds_filtered = ds[ds['surface'] < 7500]
plt.scatter(range(len(ds_filtered['surface'])), ds_filtered['surface'], color='green', alpha=0.5)
plt.xlabel('Indice')
plt.ylabel('Superficie')
plt.title('Gráfico para  "surface" (menor a 7500)')

#Sube la superficie y sube el precio
# Out:
# Text(0.5, 1.0, 'Gráfico para  "surface" (menor a 7500)')

# %% [markdown]
# **TODO: Markdown**. Escribe aquí, haz doble click en este celda y elimina este contenido y reemplázalo por el texto que quires escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias = ds['realEstate_name'].value_counts()

print(agencias)
#Cantidad: 1821
# Out:
# realEstate_name
# engel volkers madrid               470
# infocasa consulting                300
# outletdeviviendas                  260
# housell                            250
# solvia inmobiliaria                207
#                                   ...
# treixer servicios inmobiliarios      1
# tuvendesyocompro                     1
# comprarcasa noroeste                 1
# agv inmuebles                        1
# inmoproin                            1
# Name: count, Length: 1821, dtype: int64

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
mayor_casas =  ds['level5'].value_counts().index[0]
cuantas = ds['level5'].value_counts().iloc[0]

print('La poblacion con mayor catindad de casas es ' , mayor_casas , 'y el numero de casas es' , cuantas)
# Out:
# La poblacion con mayor catindad de casas es   Madrid Capital y el numero de casas es 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Has un subconjunto del Dataframe original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Pista: Filtra el Dataframe original usando la columna `level5` y la función `isin`

# %%
poblaciones = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
subconjunto = ds[ds['level5'].isin(poblaciones)]


print(subconjunto)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level5Id level6Id level7Id level8Id accuracy  \
# 1          NaN   89000  ...        0        0        0        0        1
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        1
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        1
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        1
#
#                latitude          longitude zipCode customZone   precio/mt2
# 1              40,28674           -3,79351     NaN        NaN          NaN
# 3      40,2853785786438  -3,79508142135624     NaN        NaN  1034.883721
# 85             40,35059           -3,82693     NaN        NaN  2140.000000
# 94             40,31933           -3,77574     NaN        NaN  2666.666667
# 109          40,3313411         -3,8313868     NaN        NaN  2992.957746
# ...                 ...                ...     ...        ...          ...
# 15275          40,31381           -3,83733     NaN        NaN  1769.230769
# 15291        40,3259051           -3,76318     NaN        NaN  2536.363636
# 15305        40,2882193         -3,8098617     NaN        NaN  2000.000000
# 15322          40,28282           -3,78892     NaN        NaN  1230.769231
# 15325          40,28062           -3,79869     NaN        NaN  2171.717172
#
# [907 rows x 38 columns]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barra de la media de los precios y explica lo que observas (debes usar el subconjunto obtenido de la pregunta 14) (★★★)
#
# Imprima un gráfico de barra de la media de precios y escriba en la celda Markdown un breve análisis del sector.

# %%
import matplotlib.pyplot as plt


media_precios = subconjunto.groupby('level5')['price'].mean()


plt.figure(figsize=(10, 6))
media_precios.plot(kind='bar', color='skyblue')
plt.title('Media de Precios por Poblacion')
plt.xlabel('Poblacion')
plt.ylabel('Precio Medio')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en esta celda, elimina este contenido y coloca en su lugar el texto que quieres escribir. Luego, ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza dela muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Imprime ambos valores por  cada variable.

# %%
#rooms	bathrooms	surface subconjunto


media_variables = subconjunto.groupby('level5')[['price', 'rooms', 'bathrooms', 'surface']].mean()
print(media_variables)

varianza = subconjunto.groupby('level5')[['price', 'rooms', 'bathrooms', 'surface']].var()
print(varianza)
# Out:
#                      price     rooms  bathrooms     surface
# level5
# Alcorcón     230071.052632  2.914894   1.623656  105.913295
# Fuenlabrada  177198.021459  3.025974   1.445415  103.624365
# Getafe       265040.500000  3.151724   1.865052  126.896266
# Leganés      208682.010309  2.906736   1.518135  105.852273
#                     price     rooms  bathrooms      surface
# level5
# Alcorcón     1.594783e+10  0.933895   0.592735  4244.323834
# Fuenlabrada  4.701021e+09  0.355844   0.353367  2264.643893
# Getafe       2.098267e+10  0.772748   0.658809  5828.110028
# Leganés      1.191394e+10  0.824590   0.553055  3987.475195

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
subconjunto
casa_masgrande = ds['surface'].max()

max_poblacion = subconjunto.groupby('level5')['price'].max()
max_poblacion
fuenlabrada = subconjunto[subconjunto['address'] == 'Fuenlabrada']
leganes = subconjunto[subconjunto['address'] == 'Leganés']
getafe = subconjunto[subconjunto['address'] == 'Getafe']
alcorcon = subconjunto[subconjunto['address'] == 'Alcorcón']
max_price_leganes = leganes['price'].max()
max_price_leganes_row = leganes[leganes['price'] == max_price_leganes]

max_price_leganes_address = leganes.loc[leganes['price'] == max_price_leganes, 'address'].values[0]


print(max_poblacion)
# Out:
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
subconjunto['precio_norm'] = subconjunto.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

plt.figure(figsize=(12, 6))
poblaciones = subconjunto['level5'].unique()

for poblacion in poblaciones:
    localidad = subconjunto[subconjunto['level5'] == poblacion]
    plt.hist(localidad['precio_norm'], bins=20, label=poblacion, alpha=0.6)

plt.title("Precio promedio sur de Madrid")
plt.xlabel("Precio Normalizado")
plt.ylabel("Frecuencia")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2548/272796417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['precio_norm'] = subconjunto.groupby('level5')['price'].transform(lambda x: (x - x.mean()) / x.std())

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
subconjunto['pps'] = subconjunto['price'] / subconjunto['surface']

prom_Getafe = subconjunto[subconjunto['level5'] == 'Getafe']['pps'].mean()
prom_Alcorcon = subconjunto[subconjunto['level5'] == 'Alcorcón']['pps'].mean()

print(f'Precio promedio por metro cuadrado en Getafe: {prom_Getafe:.2f}')
print(f'Precio promedio por metro cuadrado en Alcorcon: {prom_Alcorcon:.2f}')


if prom_Getafe > prom_Alcorcon:
    print('El ppm cuadrado es mayor en Getafe que en Alcorcon.')
elif prom_Getafe < prom_Alcorcon:
    print('El ppm es mayor en Alcorcon que en Getafe.')
else:
    print('El ppm es igual en Getafe y Alcorcon.')
# Out:
# Precio promedio por metro cuadrado en Getafe: 2066.31
# Precio promedio por metro cuadrado en Alcorcon: 2239.30
# El ppm es mayor en Alcorcon que en Getafe.
# /tmp/ipykernel_2548/1442052327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['pps'] = subconjunto['price'] / subconjunto['surface']

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 10), sharex=True, sharey=True)

for ax, poblacion in zip(axs.flatten(), poblaciones):
    localidad = subconjunto[subconjunto['level5'] == poblacion]
    ax.scatter(localidad['surface'], localidad['price'], label=poblacion, alpha=0.6)
    ax.set_title(f'Poblaci0n: {poblacion}')
    ax.set_xlabel('Superficie')
    ax.set_ylabel('Precio ')
    ax.legend()


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón ur de Madrid por color d cada población (debes usar el subconjunto obtenido en la pregunta 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar u código simple que transforme las columnas de coordenadas en un diccionario de python (agrega más información si es necesario) y agrégala al mapa.

# %%
import folium
subconjunto['latitude'] = subconjunto['latitude'].astype(str)
subconjunto['longitude'] = subconjunto['longitude'].astype(str)

subconjunto['latitude'] = subconjunto['latitude'].str.replace(',', '.').astype(float)
subconjunto['longitude'] = subconjunto['longitude'].str.replace(',', '.').astype(float)

coordenadas = {}
for poblacion in subconjunto['level5'].unique():
    coordenadas[poblacion] = subconjunto[subconjunto['level5'] == poblacion][['latitude', 'longitude']].values.tolist()


mapa = folium.Map(location=[40.4168, -3.7038], zoom_start=10)


colores = {'Getafe': 'blue', 'Alcorcón': 'green', 'Fuenlabrada': 'red', 'Leganés': 'purple'}


for poblacion, coords in coordenadas.items():
    for lat, lon in coords:
        folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            color=colores[poblacion],
            fill=True,
            fill_color=colores[poblacion],
            fill_opacity=0.6,
            popup=poblacion
        ).add_to(mapa)


mapa
# Out:
# /tmp/ipykernel_2548/3528646253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['latitude'] = subconjunto['latitude'].astype(str)
# /tmp/ipykernel_2548/3528646253.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['longitude'] = subconjunto['longitude'].astype(str)
# /tmp/ipykernel_2548/3528646253.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['latitude'] = subconjunto['latitude'].str.replace(',', '.').astype(float)
# /tmp/ipykernel_2548/3528646253.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subconjunto['longitude'] = subconjunto['longitude'].str.replace(',', '.').astype(float)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1dfc8f23b2e09a8a50fb0c05351c939 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1dfc8f23b2e09a8a50fb0c05351c939&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1dfc8f23b2e09a8a50fb0c05351c939 = L.map(
#                 &quot;map_a1dfc8f23b2e09a8a50fb0c05351c939&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_369ab2ac458a0e24edc0f59385bc20ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_369ab2ac458a0e24edc0f59385bc20ca.addTo(map_a1dfc8f23b2e09a8a50fb0c05351c939);
#
#
#             var circle_marker_74fe36e3a76be54c736f5b4b9db36ec8 = L.circleMarker(
#                 [40.28674, -3.79351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1dfc8f23b2e09a8a50fb0c05351c939);
#
#
#         var popup_0e0b6f100c2174241237e8073d6cf7d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_761407fdde707f937e5a8b65ae1cd193 = $(`&lt;div id=&quot;html_761407fdde707f937e5a8b65ae1cd193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuenlabrada&lt;/div&gt;`)[0];
#                 popup_0e0b6f100c2174241237e8073d6cf7d6.setContent(html_761407fdde707f937e5a8b65ae1cd193);
#
#
#
#         circle_marker_74fe36e3a76be54c736f5b4b9db36ec8.bindPopup(popup_0e0b6f100c2174241237e8073d6cf7d6)
#         ;
#
#
#
#
#             var circle_marker_5da6997eaa970145711737738b9a2546 = L.circleMarker(
#                 [40.2853785786438, -3.79508142135624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1dfc8f23b2e09a8a50fb0c05351c939);
#
#
#         var popup_01f0c8f4885e8cad86171034a8e2f524 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_951e2c25d64ca569de4a0290fb93d616 = $(`&lt;div id=&quot;html_951e2c25d64ca569de4a0290fb93d616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuenlabrada&lt;/div&gt;`)[0];
#                 popup_01f0c8f4885e8cad86171034a8e2f524.setContent(html_951e2c25d64ca569de4a0290fb93d616);
#
#
#
#         circle_marker_5da6997eaa970145711737738b9a2546.bindPopup(popup_01f0c8f4885e8cad86171034a8e2f524)
#         ;
#
#
#
#
#             var circle_marker_86727ed9a37d1a0195072eb11a460ddf = L.circleMarker(
#                 [40.2744807718156, -3.79192471504211],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1dfc8f23b2e09a8a50fb0c05351c939);
#
#
#         var popup_edd3e9b456a4838d55af88b1b2f46019 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20179673e44c2cca1a0564bff949356c = $(`&lt;div id=&quot;html_20179673e44c2cca1a0564bff949356c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuenlabrada&lt;/div&gt;`)[0];
#                 popup_edd3e9b456a4838d55af88b1b2f46019.setContent(html_20179673e44c2cca1a0564bff949356c);
#
#
#
#         circle_marker_86727ed9a37d1a0195072eb11a460ddf.bindPopup(popup_edd3e9b456a4838d55af88b1b2f46019)
#         ;
#
#
#
#
#             var circle_marker_160aa28cea0f30353479977c38e2a639 = L.circleMarker(
#                 [40.2906814213562, -3.80405242135624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quo

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
